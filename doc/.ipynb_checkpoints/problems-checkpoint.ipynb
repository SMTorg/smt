# %% [markdown]
# # List of problems
# TODO: - complete the expressions of Ndim functions
#
# ### Analytical functions
# All figures given here are a 2-D plot.
#
#
# - <font color='blue'>Sphere function (dimension = $d$)</font>
#
# <img src=files/sphere.png width=400 height=70 />
#
# \begin{equation}
# \sum\limits_{i=1}^dx_i^2,\quad-10\leq x_i\leq 10,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
#
# - <font color='blue'>Rosenbrock function (dimension = $d$)</font>
#
# <img src=files/rosenbrock.png width=400 height=70 />
#
# \begin{equation}
# \sum\limits_{i=1}^{d-1}\left[(x_{i+1}-x_i^2)^2+(x_i-1)^2\right],\quad-2\leq x_i\leq 2,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
#
# - <font color='blue'>Ndim Rosenbrock function</font>
#
#
# - <font color='blue'>Tensor Product function (dimension = $d$)</font>
#
# All figures for the tensor product function are given with $a=1$.
#
# <img src=files/cos_tensor_prod.png width=400 height=70 />
#
# \begin{equation}
# \prod\limits_{i=1}^{d}\cos(a\pi x_i),\quad-1\leq x_i\leq 1,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
# <img src=files/exp_tensor_prod.png width=400 height=70 />
#
# \begin{equation}
# \prod\limits_{i=1}^{d}\exp(x_i),\quad-1\leq x_i\leq 1,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
# <img src=files/tanh_tensor_prod.png width=400 height=70 />
#
# \begin{equation}
# \prod\limits_{i=1}^{d}\tanh(x_i),\quad-1\leq x_i\leq 1,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
# <img src=files/Gaussian_tensor_prod.png width=400 height=70 />
#
# \begin{equation}
# \prod\limits_{i=1}^{d}\exp(-2 x_i^2),\quad-1\leq x_i\leq 1,\quad\text{ for }i=1,\ldots,d.
# \end{equation}
#
# - <font color='blue'>Ndim Step function</font>
#
#
# ### Engineering functions
#
#
# - <font color='blue'>Cantilever Beam function</font>
#
#
# - <font color='blue'>Ndim Cantilever Beam function</font>
#
#
# - <font color='blue'>Robot Arm function (dimension = 8)</font>
#
# \begin{equation*}
# \sqrt{\left(\sum\limits_{i=1}^4L_i\cos\left(\sum\limits_{j=1}^i\theta_j\right)\right)^2+\left(\sum\limits_{i=1}^4L_i\sin\left(\sum\limits_{j=1}^i\theta_j\right)
# \right)^2},\quad L_i \in [0,1] \quad \text{for}\quad i=1,\dotsc,4 \quad \text{and}\quad \theta_j \in [0,2\pi]\quad\text{for}\quad j=1,\dotsc,4.
# \end{equation*}
#
#
# - <font color='blue'>Ndim Robot Arm function</font>
#
#
# - <font color='blue'>Torsion Vibration function (dimension = 15)</font>
#
# \begin{equation*}
# \frac{1}{2\pi}\sqrt{\frac{-b-\sqrt{b^2-4ac}}{2a}},
# \end{equation*}
# where $K_i=\frac{\pi G_id_i}{32L_i},\quad M_j=\frac{\rho_j \pi t_jD_j}{4g},\quad J_j=0.5M_j\frac{D_j}{2},\quad a = 1,\quad b=-\left(\frac{K_1+K2}{J_1}+\frac{K_2+K3}{J_2}\right),\quad c=\frac{K_1K_2+K_2K_3+K_3K_1}{J_1J_2},\quad \text{for}\quad d_1\in [1.8,2.2],\quad L_1\in[9,11],\quad G_1\in [105300000,128700000],\quad d_2\in [1.638,2.002],\quad L_2\in[10.8,13.2],\quad G_2\in[5580000,6820000],\quad d_3\in[2.025,2.475],\quad L_3\in[7.2,8.8],\quad G_3\in[3510000,4290000],\quad D_1\in[10.8,13.2],\quad t_1\in[2.7,3.3],\quad \rho_1\in[0.252,0.308],\quad D_2\in[12.6,15.4],\quad t_2\in[3.6,4.4],\quad\rho_1\in[0.09,0.11]$
#
#
# - <font color='blue'>Water Flow function (dimension = 8)</font>
#
# \begin{equation*}
# \frac{2\pi T_u\left(H_u-H_l\right)}{\ln\left(\frac{r}{r_w}\right)\left[1+\frac{2LT_u}{\ln\left(\frac{r}{r_w}\right)r_w^2K_w}+\frac{T_u}{T_l}\right]},\quad 0.05\leq r_w\leq 0.15,\quad 100\leq r\leq 50000,\quad 63070\leq T_u\leq 115600,\quad 990 \leq H_u \leq 1110, \quad 63.1 \leq T_l \leq 116, \quad 700 \leq H_l \leq 820, \quad 1120 \leq L \leq 1680,\quad \text{and}\quad  9855 \leq K_w \leq 12045.
# \end{equation*}
#
#
# - <font color='blue'>Welded Beam function (dimension = 3)</font>
#
# \begin{equation*}
# \sqrt{\frac{\tau'^2+\tau''^2+l\tau'\tau''}{\sqrt{0.25\left(l^2+(h+t)^2\right)}}},
# \end{equation*}
# where
# $\tau'=\frac{6000}{\sqrt{2}hl}, \quad\tau''=\frac{6000(14+0.5l)\sqrt{0.25\left(l^2+(h+t)^2\right)}}{2\left[0.707hl\left(\frac{l^2}{12}+0.25(h+t)^2\right)\right]},\quad \text{for}\quad h\in[0.125,1],\quad l,t\in[5,10]$
#
#
# - <font color='blue'>Wing Weight function (dimension = 10)</font>
#
# \begin{equation*}
# 0.036S_w^{0.758}W_{fw}^{0.0035}\left(\frac{A}{\cos^2\Lambda}\right)q^{0.006}\lambda^{0.04}\left(\frac{100tc}{\cos\Lambda}\right)^{-0.3}\left(N_zW_{dg}\right)^{0.49}+S_wW_p,\quad 150\leq S_w\leq 200,\quad 220\leq W_{fw}\leq 300,\quad 6 \leq A \leq 10,\quad -10 \leq \Lambda \leq 10,\quad 16\leq q\leq 45,\quad 0.5\leq \lambda\leq 1,\quad 0.08 \leq t_c\leq 0.18,\quad 2.5\leq N_z\leq 6,\quad 1700\leq W_{dg}\leq 25000,\quad \text{and} \quad 0.025\leq W_p\leq 0.08.
# \end{equation*}

# %% [markdown]
# # Example of execution
#
# In the following, we use methods from sampling directory to generate sampling points to be evaluated by a function from problems directory. More details about sampling methods are given [here](./sampling.html).
#
# - The Sphere example

# %%
from smt.problems import Sphere
from smt.sampling import LHS
import numpy as np

#Definition of the number of dimensions and the number of sampling points
ndim = 10
ndoe = 5

#Define the Sphere function
fun = Sphere(ndim = ndim)

#Construction of the sampling points
sampling = LHS(xlimits=fun.xlimits,criterion = 'm')#'m' for maximin criterion
xt = sampling(ndoe)

#Compute the output
yt = fun(xt)

#Compute the gradient
yd = np.zeros((ndoe,ndim))
for i in range(ndim):
    yd[:,i] = fun(xt,kx=i).T

#The final result yt and yd contain the output and the derivative, respectively.
print('Values:')
print(yt)
print('Derivatives:')
print(yd)
# Out:
# Values:
# [[ 330.18747428]
#  [ 365.54857015]
#  [ 321.07137791]
#  [ 464.91496782]
#  [ 279.58903509]]
# Derivatives:
# [[  4.88572432  13.524524    18.11844328  -8.6246839  -16.53246798
#     5.93071625   8.23845451  14.55151266  -5.09466533   9.86070613]
#  [ -7.1317248    6.98776431  11.32928068  -0.02073335   7.71499819
#    -1.63156156  18.6869698  -18.19182897 -16.16370375  15.18410059]
#  [ 14.77343202  -8.17108385  -6.09893508 -19.62399361  -7.85040878
#    -6.74206902  -7.98534029 -11.86357153   0.77530455 -16.27178458]
#  [-18.38208839 -18.79967133  -0.86887621   7.79320533  17.50164613
#   -16.37671302 -18.48854041  11.65918492   6.27357396  -3.90093119]
#  [  3.47349953  -3.95724285 -15.84766046  19.29208146  -0.87185621
#    12.21221679  -2.57866066   1.91356162  15.70612758  -7.77215523]]

# %% [markdown]
# - The Cantilever Beam problem

# %%
from smt.problems import CantileverBeam
from smt.sampling import LHS

#Definition of the number of dimensions and the number of sampling points
ndim = 12
ndoe = 15

fun = CantileverBeam(ndim = ndim)

sampling = LHS(xlimits=fun.xlimits,criterion = 'm')

xt = sampling(ndoe)
yt = fun(xt)

#Compute the gradient
yd = np.zeros((ndoe,ndim))
for i in range(ndim):
    yd[:,i] = fun(xt,kx=i).T
    
print('Values:')
print(yt)
print('Derivatives:')
print(yd)
# Out:
# Values:
# [[ 0.00684252]
#  [ 0.00664714]
#  [ 0.01898242]
#  [ 0.03024115]
#  [ 0.00608603]
#  [ 0.00435421]
#  [ 0.01054841]
#  [ 0.00894611]
#  [ 0.01458831]
#  [ 0.00910113]
#  [ 0.01980261]
#  [ 0.00973082]
#  [ 0.00803631]
#  [ 0.02220798]
#  [ 0.02014977]]
# Derivatives:
# [[ -1.30305280e-01  -1.50828005e-02   5.50628757e-03  -8.06832636e-02
#    -1.81489638e-02   7.11679840e-03  -1.41793944e-02  -3.50764284e-03
#     6.00983459e-03  -8.11897092e-03  -6.58227720e-04   6.20277791e-03]
#  [ -2.23492480e-01  -2.14034189e-02   8.04226096e-03  -4.54726164e-02
#    -8.28791308e-03   5.98286465e-03  -2.51054718e-02  -7.84333007e-03
#     7.39955586e-03  -3.14146085e-03  -8.23238909e-04   6.72812379e-03]
#  [ -1.17359272e-01  -2.64363174e-02   7.10320748e-03  -4.78707294e-01
#    -7.33330550e-02   1.84317850e-02  -1.43750320e-01  -3.93795448e-02
#     2.07717862e-02  -1.86556962e-02  -4.80741126e-03   2.01936852e-02]
#  [ -9.66278481e-01  -1.94129586e-01   3.84490227e-02  -2.50718761e-01
#    -5.12044874e-02   2.76130686e-02  -2.21929286e-01  -3.36586864e-02
#     3.23586880e-02  -8.41507129e-03  -1.17091954e-03   3.05651132e-02]
#  [ -4.89330828e-02  -1.16315801e-02   3.21056715e-03  -7.28687880e-02
#    -2.10612298e-02   6.52978804e-03  -1.56152586e-02  -5.11126901e-03
#     6.82835092e-03  -1.36443087e-02  -8.73199262e-04   7.02973515e-03]
#  [ -5.37976825e-02  -8.90381864e-03   3.00896778e-03  -4.90119612e-02
#    -6.65447681e-03   4.35891568e-03  -1.51154311e-02  -2.73686492e-03
#     3.90051220e-03  -4.85355791e-02  -3.98546831e-03   5.53077413e-03]
#  [ -2.29774883e-01  -8.55203619e-02   1.50174938e-02  -1.49932102e-02
#    -4.38240839e-03   9.94979503e-03  -1.04629411e-02  -1.76318433e-03
#     9.97576999e-03  -2.14493697e-03  -6.11693643e-04   1.01292889e-02]
#  [ -1.87257946e-01  -3.49117779e-02   8.20114984e-03  -1.28320818e-02
#    -2.92039208e-03   5.86468613e-03  -1.10621955e-01  -2.28804287e-02
#     1.10417168e-02  -6.88441781e-03  -1.34285345e-03   1.08220336e-02]
#  [ -1.74067055e-01  -4.21676597e-02   1.21137623e-02  -2.71016854e-01
#    -7.40654976e-02   1.86472108e-02  -3.46170894e-02  -3.35380327e-03
#     1.42488121e-02  -6.16410224e-04  -1.27369147e-04   1.41870296e-02]
#  [ -1.32510090e-01  -4.78622216e-02   1.13569098e-02  -2.04232623e-02
#    -3.90560926e-03   6.24553570e-03  -1.83475668e-01  -1.75711177e-02
#     1.11283047e-02  -3.38214516e-04  -7.91733102e-05   1.03469710e-02]
#  [ -7.75657753e-01  -1.20196371e-01   2.50607453e-02  -1.08866098e-01
#    -1.32310567e-02   1.63632107e-02  -2.97903157e-02  -4.70203548e-03
#     1.57801811e-02  -6.58317375e-02  -1.19982767e-02   1.92747987e-02]
#  [ -5.34845530e-02  -1.70753542e-02   5.72829741e-03  -4.57585457e-01
#    -4.44602550e-02   1.44041818e-02  -5.30541478e-03  -1.19048632e-03
#     9.33865015e-03  -1.11297829e-02  -3.09902769e-03   1.05699935e-02]
#  [ -1.68142975e-01  -2.67658386e-02   6.96890561e-03  -2.11119830e-01
#    -1.11110662e-02   8.57924239e-03  -2.36457897e-02  -5.77151939e-03
#     7.92751596e-03  -1.14821827e-03  -2.46613013e-04   7.66271896e-03]
#  [ -1.10242455e+00  -1.08120679e-01   2.59897573e-02  -1.18310049e-01
#    -5.13605329e-02   2.10579334e-02  -1.00383831e-01  -7.25311556e-03
#     2.11654890e-02  -1.07151085e-02  -2.06761940e-03   2.09012332e-02]
#  [ -4.96013403e-01  -3.28521358e-02   1.36864696e-02  -7.22109738e-01
#    -1.00034167e-01   2.41653021e-02  -7.43153376e-02  -1.02909179e-02
#     1.99882792e-02  -9.99903943e-04  -2.20698391e-04   1.97895465e-02]]
